# %%
"""
Hashiwokakero Logic Solver Demo

This script demonstrates the execution of the experiment pipeline using the
ExperimentCoordinator class.
"""

import os
import pandas as pd
from experiments import ExperimentCoordinator

# %% [markdown]
# # Ensure directories exist

# %%
if not os.path.exists('inputs'):
    print("Warning: 'inputs' folder not found. Please ensure input files are present.")

if not os.path.exists('outputs'):
    os.makedirs('outputs')

# %% [markdown]
# # Run the full experiment pipeline

# %%
coordinator = ExperimentCoordinator()

# Phase 1 & 2
results_standard = coordinator.run_phase1()
results_xlarge   = coordinator.run_phase2()

# Save & Analyze
results_combined = coordinator.save_results(results_standard, results_xlarge)
coordinator.analyze_standard_results(results_standard)
coordinator.analyze_pysat_scalability(results_xlarge)
coordinator.visualize_sample_solution()
# Out:
# ====================================================================================================
# PHASE 1: STANDARD TEST SUITE (4x4 to 25x25)
# Testing all 6 solvers on 22 puzzles
# ====================================================================================================
#
# ================================================================================
# Processing: inputs/input-01.txt
# ================================================================================
# Grid: 4x4, Islands: 5
#
#   Testing PySAT...
#     ✓ Solved in 0.0004s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.0002s
#     Nodes expanded: 5
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0002s
#     Nodes expanded: 5
#
#   Testing Naive Backtracking...
#     ✓ Solved in 0.0002s
#     Nodes expanded: 35
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 2
#     - Forbidden bridges: 0
#     - Minimum constraints: 0
#     ✓ Solved in 0.0002s
#     Nodes expanded: 3
#
#   Testing Brute Force...
#     ✓ Solved in 0.0001s
#     Combinations tried: 41
#
# ================================================================================
# Processing: inputs/input-02.txt
# ================================================================================
# Grid: 5x5, Islands: 10
#
#   Testing PySAT...
#     ✓ Solved in 0.0020s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.0005s
#     Nodes expanded: 25
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0005s
#     Nodes expanded: 10
#
#   Testing Naive Backtracking...
#     ✓ Solved in 0.0350s
#     Nodes expanded: 3,482
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 0
#     - Forbidden bridges: 1
#     - Minimum constraints: 3
#     ✓ Solved in 0.0005s
#     Nodes expanded: 10
#
#   Testing Brute Force...
#     ✓ Solved in 0.0512s
#     Combinations tried: 29,531
#
# ================================================================================
# Processing: inputs/input-03.txt
# ================================================================================
# Grid: 6x6, Islands: 15
#
#   Testing PySAT...
#     ✓ Solved in 0.0009s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.0017s
#     Nodes expanded: 125
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0021s
#     Nodes expanded: 24
#
#   Testing Naive Backtracking...
#     ✗ Failed in 0.7997s
#     Nodes expanded: 200,015
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 0
#     - Forbidden bridges: 0
#     - Minimum constraints: 4
#     ✓ Solved in 0.0013s
#     Nodes expanded: 23
#
#   Testing Brute Force...
#   Warning: 19 bridges = 1162261467 combinations, limiting to 100000
#     ✗ Failed in 0.1618s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-04.txt
# ================================================================================
# Grid: 7x7, Islands: 20
#
#   Testing PySAT...
#     ✓ Solved in 0.0013s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.0068s
#     Nodes expanded: 451
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0021s
#     Nodes expanded: 20
#
#   Testing Naive Backtracking...
#     ✗ Failed in 4.0207s
#     Nodes expanded: 200,026
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 0
#     - Forbidden bridges: 1
#     - Minimum constraints: 2
#     ✓ Solved in 0.0015s
#     Nodes expanded: 25
#
#   Testing Brute Force...
#   Warning: 26 bridges = 2541865828329 combinations, limiting to 100000
#     ✗ Failed in 0.1858s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-05.txt
# ================================================================================
# Grid: 8x8, Islands: 25
#
#   Testing PySAT...
#     ✓ Solved in 0.0017s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.1273s
#     Nodes expanded: 6,054
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0062s
#     Nodes expanded: 29
#
#   Testing Naive Backtracking...
#     ✗ Failed in 4.7273s
#     Nodes expanded: 200,047
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 2
#     - Forbidden bridges: 1
#     - Minimum constraints: 12
#     ✓ Solved in 0.0032s
#     Nodes expanded: 37
#
#   Testing Brute Force...
#   Warning: 34 bridges = 16677181699666569 combinations, limiting to 100000
#     ✗ Failed in 0.2618s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-06.txt
# ================================================================================
# Grid: 9x9, Islands: 30
#
#   Testing PySAT...
#     ✓ Solved in 0.0037s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.0465s
#     Nodes expanded: 1,763
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0082s
#     Nodes expanded: 33
#
#   Testing Naive Backtracking...
#     ✗ Failed in 5.5421s
#     Nodes expanded: 200,056
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 0
#     - Forbidden bridges: 4
#     - Minimum constraints: 8
#     ✓ Solved in 0.0854s
#     Nodes expanded: 37
#
#   Testing Brute Force...
#   Warning: 42 bridges = 109418989131512359209 combinations, limiting to 100000
#     ✗ Failed in 0.1939s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-07.txt
# ================================================================================
# Grid: 10x10, Islands: 35
#
#   Testing PySAT...
#     ✓ Solved in 0.0026s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.1933s
#     Nodes expanded: 8,975
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0118s
#     Nodes expanded: 47
#
#   Testing Naive Backtracking...
#     ✗ Failed in 5.3529s
#     Nodes expanded: 200,066
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 2
#     - Forbidden bridges: 4
#     - Minimum constraints: 7
#     ✓ Solved in 0.0036s
#     Nodes expanded: 38
#
#   Testing Brute Force...
#   Warning: 50 bridges = 717897987691852588770249 combinations, limiting to 100000
#     ✗ Failed in 0.2106s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-08.txt
# ================================================================================
# Grid: 11x11, Islands: 40
#
#   Testing PySAT...
#     ✓ Solved in 0.0033s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.3998s
#     Nodes expanded: 16,761
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0182s
#     Nodes expanded: 55
#
#   Testing Naive Backtracking...
#     ✗ Failed in 9.7486s
#     Nodes expanded: 200,089
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 12
#     - Forbidden bridges: 0
#     - Minimum constraints: 9
#     ✓ Solved in 0.0042s
#     Nodes expanded: 39
#
#   Testing Brute Force...
#   Warning: 59 bridges = 14130386091738734504764811067 combinations, limiting to 100000
#     ✗ Failed in 0.2312s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-09.txt
# ================================================================================
# Grid: 12x12, Islands: 50
#
#   Testing PySAT...
#     ✓ Solved in 0.0047s
#
#   Testing A* (Simple)...
#     ✗ Failed in 2.6607s
#     Nodes expanded: 100,001
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0404s
#     Nodes expanded: 91
#
#   Testing Naive Backtracking...
#     ✗ Failed in 7.4362s
#     Nodes expanded: 200,123
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 3
#     - Forbidden bridges: 2
#     - Minimum constraints: 22
#     ✓ Solved in 0.0179s
#     Nodes expanded: 97
#
#   Testing Brute Force...
#   Warning: 76 bridges = 1824800363140073127359051977856583921 combinations, limiting to 100000
#     ✗ Failed in 0.3038s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-10.txt
# ================================================================================
# Grid: 13x13, Islands: 60
#
#   Testing PySAT...
#     ✓ Solved in 0.0066s
#
#   Testing A* (Simple)...
#     ✗ Failed in 5.0203s
#     Nodes expanded: 100,001
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.1680s
#     Nodes expanded: 250
#
#   Testing Naive Backtracking...
#     ✗ Failed in 12.7398s
#     Nodes expanded: 200,159
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 13
#     - Forbidden bridges: 1
#     - Minimum constraints: 12
#     ✓ Solved in 0.0781s
#     Nodes expanded: 101
#
#   Testing Brute Force...
#   Warning: 94 bridges = 706965049015104706497203195837614914543357369 combinations, limiting to 100000
#     ✗ Failed in 0.3236s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-11.txt
# ================================================================================
# Grid: 14x14, Islands: 70
#
#   Testing PySAT...
#     ✓ Solved in 0.0086s
#
#   Testing A* (Simple)...
#     ✗ Failed in 4.2563s
#     Nodes expanded: 100,001
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0726s
#     Nodes expanded: 91
#
#   Testing Naive Backtracking...
#     ✗ Failed in 15.3817s
#     Nodes expanded: 200,177
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 9
#     - Forbidden bridges: 3
#     - Minimum constraints: 23
#     ✓ Solved in 0.0221s
#     Nodes expanded: 112
#
#   Testing Brute Force...
#   Warning: 112 bridges = 273892744995340833777347939263771534786080723599733441 combinations, limiting to 100000
#     ✗ Failed in 0.3410s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-12.txt
# ================================================================================
# Grid: 15x15, Islands: 80
#
#   Testing PySAT...
#     ✓ Solved in 0.0113s
#
#   Testing A* (Simple)...
#     ✗ Failed in 6.2861s
#     Nodes expanded: 100,001
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.1934s
#     Nodes expanded: 183
#
#   Testing Naive Backtracking...
#     ✗ Failed in 9.1747s
#     Nodes expanded: 200,220
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 6
#     - Forbidden bridges: 3
#     - Minimum constraints: 29
#     ✓ Solved in 0.0367s
#     Nodes expanded: 165
#
#   Testing Brute Force...
#   Warning: 130 bridges = 106111661199647248543687855752712667991103904330482569981872649 combinations, limiting to 100000
#     ✗ Failed in 0.3753s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-13.txt
# ================================================================================
# Grid: 16x16, Islands: 90
#
#   Testing PySAT...
#     ✓ Solved in 0.1033s
#
#   Testing A* (Simple)...
#     ✗ Failed in 9.4971s
#     Nodes expanded: 100,001
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.7738s
#     Nodes expanded: 576
#
#   Testing Naive Backtracking...
#     ✗ Failed in 15.5925s
#     Nodes expanded: 200,241
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 10
#     - Forbidden bridges: 6
#     - Minimum constraints: 27
#     ✓ Solved in 0.0338s
#     Nodes expanded: 116
#
#   Testing Brute Force...
#   Warning: 148 bridges = 41109831670569663658300086939077404909608122265524774868353822811305361 combinations, limiting to 100000
#     ✗ Failed in 0.4188s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-14.txt
# ================================================================================
# Grid: 17x17, Islands: 100
#
#   Testing PySAT...
#     ✓ Solved in 0.0157s
#
#   Testing A* (Simple)...
#     ✗ Failed in 10.3384s
#     Nodes expanded: 100,001
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.3583s
#     Nodes expanded: 239
#
#   Testing Naive Backtracking...
#     ✗ Failed in 24.0173s
#     Nodes expanded: 200,260
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 8
#     - Forbidden bridges: 10
#     - Minimum constraints: 14
#     ✓ Solved in 0.1117s
#     Nodes expanded: 368
#
#   Testing Brute Force...
#   Warning: 166 bridges = 15926791088519786003064148590679881418931379526481396121112548658575277686941529 combinations, limiting to 100000
#     ✗ Failed in 0.4489s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-15.txt
# ================================================================================
# Grid: 18x18, Islands: 110
#
#   Testing PySAT...
#     ✓ Solved in 0.0172s
#
#   Testing A* (Simple)...
#     ✗ Failed in 10.7189s
#     Nodes expanded: 100,001
#
#   Testing A* (Advanced)...
#     ✓ Solved in 3.3948s
#     Nodes expanded: 1,795
#
#   Testing Naive Backtracking...
#     ✗ Failed in 31.0606s
#     Nodes expanded: 200,297
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 10
#     - Forbidden bridges: 8
#     - Minimum constraints: 14
#     ✓ Solved in 0.3277s
#     Nodes expanded: 591
#
#   Testing Brute Force...
#   Warning: 184 bridges = 6170365191715177779482467945369860501784408913594010934644126825341528124785676079587681 combinations, limiting to 100000
#     ✗ Failed in 0.4897s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-16.txt
# ================================================================================
# Grid: 19x19, Islands: 120
#
#   Testing PySAT...
#     ✓ Solved in 0.0201s
#
#   Testing A* (Simple)...
#     ✗ Failed in 8.0711s
#     Nodes expanded: 100,001
#
#   Testing A* (Advanced)...
#     ✓ Solved in 6.0776s
#     Nodes expanded: 2,672
#
#   Testing Naive Backtracking...
#     ✗ Failed in 23.9707s
#     Nodes expanded: 200,345
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 11
#     - Forbidden bridges: 3
#     - Minimum constraints: 15
#     ✓ Solved in 1.0412s
#     Nodes expanded: 1,857
#
#   Testing Brute Force...
#   Warning: 202 bridges = 2390525899882872924049031898322016641463101073880550463771174655651832418111719646949462291396009 combinations, limiting to 100000
#     ✗ Failed in 0.5211s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-17.txt
# ================================================================================
# Grid: 20x20, Islands: 130
#
#   Testing PySAT...
#     ✓ Solved in 0.0222s
#
#   Testing A* (Simple)...
#     ✗ Failed in 10.2570s
#     Nodes expanded: 100,001
#
#   Testing A* (Advanced)...
#     ✓ Solved in 15.7965s
#     Nodes expanded: 5,194
#
#   Testing Naive Backtracking...
#     ✗ Failed in 22.3967s
#     Nodes expanded: 200,374
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 8
#     - Forbidden bridges: 6
#     - Minimum constraints: 34
#     ✓ Solved in 0.7331s
#     Nodes expanded: 1,774
#
#   Testing Brute Force...
#   Warning: 220 bridges = 926138713099787670959935798024513966701772293499227988263405269197039529170894882252068039219702299428401 combinations, limiting to 100000
#     ✗ Failed in 0.5541s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-18.txt
# ================================================================================
# Grid: 21x21, Islands: 140
#
#   Testing PySAT...
#     ✓ Solved in 0.0252s
#
#   Testing A* (Simple)...
#     ✗ Failed in 12.4941s
#     Nodes expanded: 100,001
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.3907s
#     Nodes expanded: 2,332
#
#   Testing Naive Backtracking...
#     ✗ Failed in 22.3886s
#     Nodes expanded: 200,415
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 18
#     - Forbidden bridges: 3
#     - Minimum constraints: 29
#     ✓ Solved in 0.1232s
#     Nodes expanded: 260
#
#   Testing Brute Force...
#   Warning: 238 bridges = 358805113110950445279469426279262434966930339114122428335494730197493691743717859849693621015768243278975535908089 combinations, limiting to 100000
#     ✗ Failed in 0.5735s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-19.txt
# ================================================================================
# Grid: 22x22, Islands: 155
#
#   Testing PySAT...
#     ✓ Solved in 0.1179s
#
#   Testing A* (Simple)...
#     ✗ Failed in 12.6763s
#     Nodes expanded: 100,001
#
#   Testing A* (Advanced)...
#     ✗ Failed in 60.0596s
#     Nodes expanded: 15,988
#
#   Testing Naive Backtracking...
#     ✗ Failed in 25.5629s
#     Nodes expanded: 200,479
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 27
#     - Forbidden bridges: 7
#     - Minimum constraints: 42
#     ✓ Solved in 0.3102s
#     Nodes expanded: 350
#
#   Testing Brute Force...
#   Warning: 266 bridges = 8208310104418019325036929470142710287591508921392837069266273277769200052715078275880213466781018332653457038503871962768079529 combinations, limiting to 100000
#     ✗ Failed in 0.6335s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-20.txt
# ================================================================================
# Grid: 23x23, Islands: 170
#
#   Testing PySAT...
#     ✓ Solved in 0.0372s
#
#   Testing A* (Simple)...
#     ✗ Failed in 14.6591s
#     Nodes expanded: 100,001
#
#   Testing A* (Advanced)...
#     ✗ Failed in 60.0494s
#     Nodes expanded: 10,807
#
#   Testing Naive Backtracking...
#     ✗ Failed in 29.2302s
#     Nodes expanded: 200,508
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 9
#     - Forbidden bridges: 5
#     - Minimum constraints: 28
#     ✓ Solved in 5.0827s
#     Nodes expanded: 1,366
#
#   Testing Brute Force...
#   Warning: 294 bridges = 187779806664730282566976717945251462231088745713768774309300672261137170339504906164334987867886065004458826393138537781637191677319198593369 combinations, limiting to 100000
#     ✗ Failed in 0.6813s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-21.txt
# ================================================================================
# Grid: 24x24, Islands: 185
#
#   Testing PySAT...
#     ✓ Solved in 0.0393s
#
#   Testing A* (Simple)...
#     ✗ Failed in 13.6393s
#     Nodes expanded: 100,001
#
#   Testing A* (Advanced)...
#     ✗ Failed in 60.0026s
#     Nodes expanded: 13,310
#
#   Testing Naive Backtracking...
#     ✗ Failed in 35.0980s
#     Nodes expanded: 200,578
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 12
#     - Forbidden bridges: 4
#     - Minimum constraints: 28
#     ✓ Solved in 12.7282s
#     Nodes expanded: 16,890
#
#   Testing Brute Force...
#   Warning: 322 bridges = 4295799664301737030378306532230479662246023677353146624650770473311947881924651276132500949208163404166795664453532670663357741137600786532015103485753609 combinations, limiting to 100000
#     ✗ Failed in 0.7765s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-22.txt
# ================================================================================
# Grid: 25x25, Islands: 200
#
#   Testing PySAT...
#     ✓ Solved in 0.0724s
#
#   Testing A* (Simple)...
#     ✗ Failed in 15.2110s
#     Nodes expanded: 100,001
#
#   Testing A* (Advanced)...
#     ✗ Failed in 60.0011s
#     Nodes expanded: 10,624
#
#   Testing Naive Backtracking...
#     ✗ Failed in 36.2694s
#     Nodes expanded: 200,582
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 0
#     - Forbidden bridges: 19
#     - Minimum constraints: 12
#     ✗ Failed in 60.0084s
#     Nodes expanded: 95,975
#
#   Testing Brute Force...
#   Warning: 350 bridges = 98274117348321974353044780928022697503543794108996224149902690255438168118107927224939057895356483251830948245334782867413814443266637838233302304694183773324275704249 combinations, limiting to 100000
#     ✗ Failed in 0.8215s
#     Combinations tried: 100,001
#
# ====================================================================================================
# PHASE 2: EXTRA LARGE PUZZLES (30x30 to 40x40)
# Testing PySAT only on 3 extreme puzzles
# ====================================================================================================
#
# ================================================================================
# Processing: inputs/input-23.txt
# ================================================================================
# Grid: 30x30, Islands: 300
#
#   Testing PySAT (only viable solver for this size)...
#     ✓ Solved in 0.1752s
#     Variables: 2,160
#     Clauses: 17,544
#
# ================================================================================
# Processing: inputs/input-24.txt
# ================================================================================
# Grid: 35x35, Islands: 400
#
#   Testing PySAT (only viable solver for this size)...
#     ✓ Solved in 0.1525s
#     Variables: 2,920
#     Clauses: 24,377
#
# ================================================================================
# Processing: inputs/input-25.txt
# ================================================================================
# Grid: 40x40, Islands: 500
#
#   Testing PySAT (only viable solver for this size)...
#     ✓ Solved in 0.3309s
#     Variables: 3,680
#     Clauses: 31,349
#
# ✓ Complete results saved to 'solver_results_complete.csv'
# ✓ Standard test results saved to 'solver_results_standard.csv'
#
# ====================================================================================================
# ANALYSIS: STANDARD TEST SUITE (All Solvers)
# ====================================================================================================
#
# Generating standard test visualizations...
# /mnt/d/CSAI/experiments.py:310: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   successful.loc[:, 'efficiency'] = successful['num_islands'] / successful['solve_time']
# ====================================================================================================
# SUMMARY RESULTS
# ====================================================================================================
#
# Average Solve Time (seconds):
# grid_size                    4x4       5x5       6x6       7x7       8x8       9x9     10x10     11x11     12x12      13x13      14x14     15x15      16x16      17x17      18x18      19x19      20x20      21x21      22x22      23x23      24x24      25x25
# solver
# A* (Advanced)           0.000179  0.000536  0.002105  0.002126  0.006173  0.008243  0.011823  0.018198  0.040385   0.168016   0.072580  0.193398   0.773754   0.358319   3.394835   6.077578  15.796471   0.390672  60.059590  60.049383  60.002643  60.001055
# A* (Simple)             0.000166  0.000469  0.001707  0.006801  0.127318  0.046537  0.193311  0.399783  2.660728   5.020323   4.256264  6.286053   9.497088  10.338436  10.718946   8.071085  10.257007  12.494058  12.676350  14.659143  13.639293  15.211018
# Brute Force             0.000096  0.051178  0.161777  0.185822  0.261798  0.193929  0.210552  0.231157  0.303836   0.323599   0.341040  0.375277   0.418769   0.448870   0.489653   0.521107   0.554091   0.573464   0.633520   0.681255   0.776510   0.821489
# Naive Backtracking      0.000180  0.034950  0.799703  4.020727  4.727277  5.542092  5.352933  9.748562  7.436247  12.739816  15.381727  9.174686  15.592456  24.017306  31.060583  23.970682  22.396714  22.388628  25.562874  29.230173  35.097999  36.269363
# Optimized Backtracking  0.000158  0.000458  0.001270  0.001522  0.003177  0.085416  0.003576  0.004162  0.017928   0.078073   0.022099  0.036690   0.033789   0.111652   0.327704   1.041220   0.733084   0.123164   0.310196   5.082744  12.728201  60.008433
# PySAT                   0.000350  0.002020  0.000942  0.001298  0.001711  0.003660  0.002609  0.003302  0.004691   0.006569   0.008614  0.011296   0.103288   0.015670   0.017219   0.020051   0.022199   0.025152   0.117942   0.037184   0.039323   0.072395
#
#
# Average Nodes Expanded:
# grid_size                4x4      5x5       6x6       7x7       8x8       9x9     10x10     11x11     12x12     13x13     14x14     15x15     16x16     17x17     18x18     19x19     20x20     21x21     22x22     23x23     24x24     25x25
# solver
# A* (Advanced)            5.0     10.0      24.0      20.0      29.0      33.0      47.0      55.0      91.0     250.0      91.0     183.0     576.0     239.0    1795.0    2672.0    5194.0    2332.0   15988.0   10807.0   13310.0   10624.0
# A* (Simple)              5.0     25.0     125.0     451.0    6054.0    1763.0    8975.0   16761.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0
# Brute Force             41.0  29531.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0  100001.0
# Naive Backtracking      35.0   3482.0  200015.0  200026.0  200047.0  200056.0  200066.0  200089.0  200123.0  200159.0  200177.0  200220.0  200241.0  200260.0  200297.0  200345.0  200374.0  200415.0  200479.0  200508.0  200578.0  200582.0
# Optimized Backtracking   3.0     10.0      23.0      25.0      37.0      37.0      38.0      39.0      97.0     101.0     112.0     165.0     116.0     368.0     591.0    1857.0    1774.0     260.0     350.0    1366.0   16890.0   95975.0
#
# ====================================================================================================
# DETAILED ANALYSIS REPORT
# ====================================================================================================
#
# 1. OVERALL STATISTICS
# ----------------------------------------------------------------------------------------------------
# Total test cases: 132
# Successful solves: 73 (55.3%)
# Average solve time (successful): 0.6773s
#
# 2. PER-SOLVER PERFORMANCE
# ----------------------------------------------------------------------------------------------------
#
# PySAT:
#   Success rate: 22/22 (100.0%)
#   Avg solve time: 0.0235s
#   Min solve time: 0.0004s
#   Max solve time: 0.1179s
#
# A* (Simple):
#   Success rate: 8/22 (36.4%)
#   Avg solve time: 0.0970s
#   Min solve time: 0.0002s
#   Max solve time: 0.3998s
#   Avg nodes expanded: 4270
#
# A* (Advanced):
#   Success rate: 18/22 (81.8%)
#   Avg solve time: 1.5175s
#   Min solve time: 0.0002s
#   Max solve time: 15.7965s
#   Avg nodes expanded: 758
#
# Naive Backtracking:
#   Success rate: 2/22 (9.1%)
#   Avg solve time: 0.0176s
#   Min solve time: 0.0002s
#   Max solve time: 0.0350s
#   Avg nodes expanded: 1758
#
# Optimized Backtracking:
#   Success rate: 21/22 (95.5%)
#   Avg solve time: 0.9879s
#   Min solve time: 0.0002s
#   Max solve time: 12.7282s
#   Avg nodes expanded: 1155
#
# Brute Force:
#   Success rate: 2/22 (9.1%)
#   Avg solve time: 0.0256s
#   Min solve time: 0.0001s
#   Max solve time: 0.0512s
#   Avg nodes expanded: 14786
#
# 3. PROBLEM SIZE ANALYSIS
# ----------------------------------------------------------------------------------------------------
#
# 10x10:
#   Success rate: 66.7%
#   Average solve time: 0.0528s
#   Best solver: PySAT
#
# 11x11:
#   Success rate: 66.7%
#   Average solve time: 0.1064s
#   Best solver: PySAT
#
# 12x12:
#   Success rate: 50.0%
#   Average solve time: 0.0210s
#   Best solver: PySAT
#
# 13x13:
#   Success rate: 50.0%
#   Average solve time: 0.0842s
#   Best solver: PySAT
#
# 14x14:
#   Success rate: 50.0%
#   Average solve time: 0.0344s
#   Best solver: PySAT
#
# 15x15:
#   Success rate: 50.0%
#   Average solve time: 0.0805s
#   Best solver: PySAT
#
# 16x16:
#   Success rate: 50.0%
#   Average solve time: 0.3036s
#   Best solver: Optimized Backtracking
#
# 17x17:
#   Success rate: 50.0%
#   Average solve time: 0.1619s
#   Best solver: PySAT
#
# 18x18:
#   Success rate: 50.0%
#   Average solve time: 1.2466s
#   Best solver: PySAT
#
# 19x19:
#   Success rate: 50.0%
#   Average solve time: 2.3796s
#   Best solver: PySAT
#
# 20x20:
#   Success rate: 50.0%
#   Average solve time: 5.5173s
#   Best solver: PySAT
#
# 21x21:
#   Success rate: 50.0%
#   Average solve time: 0.1797s
#   Best solver: PySAT
#
# 22x22:
#   Success rate: 33.3%
#   Average solve time: 0.2141s
#   Best solver: PySAT
#
# 23x23:
#   Success rate: 33.3%
#   Average solve time: 2.5600s
#   Best solver: PySAT
#
# 24x24:
#   Success rate: 33.3%
#   Average solve time: 6.3838s
#   Best solver: PySAT
#
# 25x25:
#   Success rate: 16.7%
#   Average solve time: 0.0724s
#   Best solver: PySAT
#
# 4x4:
#   Success rate: 100.0%
#   Average solve time: 0.0002s
#   Best solver: Brute Force
#
# 5x5:
#   Success rate: 100.0%
#   Average solve time: 0.0149s
#   Best solver: Optimized Backtracking
#
# 6x6:
#   Success rate: 66.7%
#   Average solve time: 0.0015s
#   Best solver: PySAT
#
# 7x7:
#   Success rate: 66.7%
#   Average solve time: 0.0029s
#   Best solver: PySAT
#
# 8x8:
#   Success rate: 66.7%
#   Average solve time: 0.0346s
#   Best solver: PySAT
#
# 9x9:
#   Success rate: 66.7%
#   Average solve time: 0.0360s
#   Best solver: PySAT
#
# ====================================================================================================
# ANALYSIS: PYSAT SCALABILITY (4x4 to 40x40)
# ====================================================================================================
#
# PySAT Performance Across All Puzzle Sizes:
# ----------------------------------------------------------------------------------------------------
# Grid Size    Islands    Success    Time (s)     Variables    Clauses
# ----------------------------------------------------------------------------------------------------
# 30x30        300        ✓          0.1752       2,160        17,544
# 35x35        400        ✓          0.1525       2,920        24,377
# 40x40        500        ✓          0.3309       3,680        31,349
#
# Generating PySAT scalability visualization...
# PySAT Statistical Summary:
# ----------------------------------------------------------------------------------------------------
# Total puzzles tested: 3
# Successful solves: 3
# Success rate: 100.0%
#
# Smallest puzzle: 300 islands
# Largest puzzle: 500 islands
#
# Fastest solve: 0.1525s (35x35)
# Slowest solve: 0.3309s (40x40)
# Average solve time: 0.2195s
#
# Max variables: 3,680 (40x40)
# Max clauses: 31,349 (40x40)
#
# ====================================================================================================
# SAMPLE SOLUTION VISUALIZATION
# ====================================================================================================
# Visualization error: [Errno 2] No such file or directory: 'input-07.txt'
