# %%
"""
Hashiwokakero Logic Solver Demo

This script demonstrates the execution of the experiment pipeline using the
ExperimentCoordinator class.
"""

import os
import pandas as pd
from experiments import ExperimentCoordinator

# %% [markdown]
# # Ensure directories exist

# %%
if not os.path.exists('inputs'):
    print("Warning: 'inputs' folder not found. Please ensure input files are present.")

if not os.path.exists('outputs'):
    os.makedirs('outputs')

# %% [markdown]
# # Run the full experiment pipeline

# %%
coordinator = ExperimentCoordinator()

# Phase 1 & 2
results_standard = coordinator.run_phase1()
results_xlarge   = coordinator.run_phase2()

# Save & Analyze
results_combined = coordinator.save_results(results_standard, results_xlarge)
coordinator.analyze_standard_results(results_standard)
coordinator.analyze_pysat_scalability(results_xlarge)
coordinator.visualize_sample_solution()
# Out:
# ====================================================================================================
# PHASE 1: STANDARD TEST SUITE (4x4 to 25x25)
# Testing all 6 solvers on 22 puzzles
# ====================================================================================================
#
# ================================================================================
# Processing: inputs/input-01.txt
# ================================================================================
# Grid: 4x4, Islands: 5
#
#   Testing PySAT...
#     ✓ Solved in 0.0003s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.0001s
#     Nodes expanded: 5
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0002s
#     Nodes expanded: 5
#
#   Testing Naive Backtracking...
#     ✓ Solved in 0.0002s
#     Nodes expanded: 35
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 2
#     - Forbidden bridges: 0
#     - Minimum constraints: 0
#     ✓ Solved in 0.0002s
#     Nodes expanded: 3
#
#   Testing Brute Force...
#     ✓ Solved in 0.0001s
#     Combinations tried: 41
#
# ================================================================================
# Processing: inputs/input-02.txt
# ================================================================================
# Grid: 5x5, Islands: 10
#
#   Testing PySAT...
#     ✓ Solved in 0.0003s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.0003s
#     Nodes expanded: 25
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0004s
#     Nodes expanded: 10
#
#   Testing Naive Backtracking...
#     ✓ Solved in 0.0328s
#     Nodes expanded: 3,482
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 0
#     - Forbidden bridges: 1
#     - Minimum constraints: 3
#     ✓ Solved in 0.0004s
#     Nodes expanded: 10
#
#   Testing Brute Force...
#     ✓ Solved in 0.0480s
#     Combinations tried: 29,531
#
# ================================================================================
# Processing: inputs/input-03.txt
# ================================================================================
# Grid: 6x6, Islands: 15
#
#   Testing PySAT...
#     ✓ Solved in 0.0009s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.0017s
#     Nodes expanded: 125
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0021s
#     Nodes expanded: 24
#
#   Testing Naive Backtracking...
#     ✗ Failed in 3.0849s
#     Nodes expanded: 200,015
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 0
#     - Forbidden bridges: 0
#     - Minimum constraints: 4
#     ✓ Solved in 0.0012s
#     Nodes expanded: 23
#
#   Testing Brute Force...
#   Warning: 19 bridges = 1162261467 combinations, limiting to 100000
#     ✗ Failed in 0.1621s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-04.txt
# ================================================================================
# Grid: 7x7, Islands: 20
#
#   Testing PySAT...
#     ✓ Solved in 0.0012s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.0067s
#     Nodes expanded: 451
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0020s
#     Nodes expanded: 20
#
#   Testing Naive Backtracking...
#     ✗ Failed in 3.6780s
#     Nodes expanded: 200,026
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 0
#     - Forbidden bridges: 1
#     - Minimum constraints: 2
#     ✓ Solved in 0.0015s
#     Nodes expanded: 25
#
#   Testing Brute Force...
#   Warning: 26 bridges = 2541865828329 combinations, limiting to 100000
#     ✗ Failed in 0.1803s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-05.txt
# ================================================================================
# Grid: 8x8, Islands: 25
#
#   Testing PySAT...
#     ✓ Solved in 0.0018s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.1186s
#     Nodes expanded: 6,054
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0054s
#     Nodes expanded: 29
#
#   Testing Naive Backtracking...
#     ✗ Failed in 4.1212s
#     Nodes expanded: 200,047
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 2
#     - Forbidden bridges: 1
#     - Minimum constraints: 12
#     ✓ Solved in 0.0028s
#     Nodes expanded: 37
#
#   Testing Brute Force...
#   Warning: 34 bridges = 16677181699666569 combinations, limiting to 100000
#     ✗ Failed in 0.1921s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-06.txt
# ================================================================================
# Grid: 9x9, Islands: 30
#
#   Testing PySAT...
#     ✓ Solved in 0.0030s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.0363s
#     Nodes expanded: 1,763
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0066s
#     Nodes expanded: 33
#
#   Testing Naive Backtracking...
#     ✗ Failed in 5.1882s
#     Nodes expanded: 200,056
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 0
#     - Forbidden bridges: 4
#     - Minimum constraints: 8
#     ✓ Solved in 0.0040s
#     Nodes expanded: 37
#
#   Testing Brute Force...
#   Warning: 42 bridges = 109418989131512359209 combinations, limiting to 100000
#     ✗ Failed in 0.2232s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-07.txt
# ================================================================================
# Grid: 10x10, Islands: 35
#
#   Testing PySAT...
#     ✓ Solved in 0.0026s
#
#   Testing A* (Simple)...
#     ✓ Solved in 0.2092s
#     Nodes expanded: 8,975
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0121s
#     Nodes expanded: 47
#
#   Testing Naive Backtracking...
#     ✗ Failed in 5.2742s
#     Nodes expanded: 200,066
#
#   Testing Optimized Backtracking...
#   Constraint Propagation Results:
#     - Forced bridges: 2
#     - Forbidden bridges: 4
#     - Minimum constraints: 7
#     ✓ Solved in 0.0037s
#     Nodes expanded: 38
#
#   Testing Brute Force...
#   Warning: 50 bridges = 717897987691852588770249 combinations, limiting to 100000
#     ✗ Failed in 0.2273s
#     Combinations tried: 100,001
#
# ================================================================================
# Processing: inputs/input-08.txt
# ================================================================================
# Grid: 11x11, Islands: 40
#
#   Testing PySAT...
#     ✓ Solved in 0.0039s
#
#   Testing A* (Simple)...
#     ✓ Solved in 4.3173s
#     Nodes expanded: 16,761
#
#   Testing A* (Advanced)...
#     ✓ Solved in 0.0191s
#     Nodes expanded: 55
#
#   Testing Naive Backtracking...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 4
#       1 coordinator = ExperimentCoordinator()
#       3 # Phase 1 & 2
# ----> 4 results_standard = coordinator.run_phase1()
#       5 results_xlarge   = coordinator.run_phase2()
#       7 # Save & Analyze
#
# File /mnt/d/CSAI/experiments.py:598, in ExperimentCoordinator.run_phase1(self)
#     595 print("="*100)
#     597 runner = ExperimentRunner(self.input_files_standard)
# --> 598 return runner.run_all_experiments()
#
# File /mnt/d/CSAI/experiments.py:45, in ExperimentRunner.run_all_experiments(self)
#      43 try:
#      44     solver = solver_factory(puzzle)
# ---> 45     success, solution = solver.solve()
#      46     stats = solver.get_stats()
#      48     result = {
#      49         'input_file': input_file,
#      50         'grid_size': grid_size,
#    (...)     58         'num_clauses': stats.get('num_clauses', 0)
#      59     }
#
# File /mnt/d/CSAI/solvers.py:504, in NaiveBacktrackingSolver.solve(self)
#     502 self.start_time = start_time
#     503 assignment = {}
# --> 504 success = self._backtrack_naive(assignment, 0)
#     506 self.solve_time = time.time() - start_time
#     508 if success:
#
# File /mnt/d/CSAI/solvers.py:536, in NaiveBacktrackingSolver._backtrack_naive(self, assignment, bridge_index)
#     534 # Basic check: not exceeding island capacity
#     535 if self._is_consistent(assignment):
# --> 536     if self._backtrack_naive(assignment, bridge_index + 1):
#     537         return True
#     539 # Backtrack
#
# File /mnt/d/CSAI/solvers.py:536, in NaiveBacktrackingSolver._backtrack_naive(self, assignment, bridge_index)
#     534 # Basic check: not exceeding island capacity
#     535 if self._is_consistent(assignment):
# --> 536     if self._backtrack_naive(assignment, bridge_index + 1):
#     537         return True
#     539 # Backtrack
#
#     [... skipping similar frames: NaiveBacktrackingSolver._backtrack_naive at line 536 (56 times)]
#
# File /mnt/d/CSAI/solvers.py:536, in NaiveBacktrackingSolver._backtrack_naive(self, assignment, bridge_index)
#     534 # Basic check: not exceeding island capacity
#     535 if self._is_consistent(assignment):
# --> 536     if self._backtrack_naive(assignment, bridge_index + 1):
#     537         return True
#     539 # Backtrack
#
# File /mnt/d/CSAI/solvers.py:526, in NaiveBacktrackingSolver._backtrack_naive(self, assignment, bridge_index)
#     524 # Base case: all bridges assigned
#     525 if bridge_index >= len(self.all_bridges):
# --> 526     return self._is_complete_valid_solution(assignment)
#     528 bridge = self.all_bridges[bridge_index]
#     530 # Try all values: 0, 1, 2 (no intelligent ordering)
#
# File /mnt/d/CSAI/solvers.py:574, in NaiveBacktrackingSolver._is_complete_valid_solution(self, assignment)
#     572     island1, island2 = bridge_key
#     573     island_counts[island1] += num_bridges
# --> 574     island_counts[island2] += num_bridges
#     576 # Check all islands satisfied
#     577 for island_pos, required in self.island_requirements.items():
#
# KeyboardInterrupt:
